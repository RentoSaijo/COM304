# %% [markdown]
# # COM304: Algorithms
# ##### notebook code (C) 2021-2024 Timothy James Becker
# ## HW1: working with sums, products and bounds

# %% [markdown]
# Instructions: add a new markdown cell after each problem if it is not already there (this is easier than trying to continue in the question cell) and then create your solution using LaTex that has been surrounded by $$. You should save your HW1.ipynb as COM304_FirstName_LastName_HW1.ipynb so that these will be easy to read and therefore grade. FirstName and LastName in that should be your actual names. For example if you name was Prinny Monk you would name your assignment: COM304_Prinny_Monk_HW1.ipynb. A nice LaTex guide can be found [here](https://en.wikibooks.org/wiki/LaTeX/Mathematics)

# %% [markdown]
# Use CLRV:Appendix A methods to create a closed form or bound (IE no sigma notation, no ...):

# %% [markdown]
# <h3 style="display:inline">(1)</h3> Assuming a sequence $a_1, a_2, ... a_n$ and $b_1,b_2,...,b_n$ and $c_1,c_2,...,c_n$ and $d,f,g \in \mathbb{R}$:  $\displaystyle\sum_{i=1}^{n}(da_i^2+fb_i-gc_i)$

# %% [markdown]
# <h3 style="display:inline">(2)</h3> $\displaystyle\sum_{i=0}^{n}(i-1+3n+i)$

# %% [markdown]
# <h3 style="display:inline">(3)</h3> $\displaystyle\sum_{i=10}^{20}(i+3n+i^2)$

# %% [markdown]
# <h3 style="display:inline">(4)</h3> $\displaystyle\prod_{i=n-10}^{n}(3i+n)$

# %% [markdown]
# <h3 style="display:inline">(5)</h3> $\displaystyle\sum_{k=0}^{n/2}(k^2-k+c)$

# %% [markdown]
# <h3 style="display:inline">(6)</h3> $\displaystyle\prod_{k=0}^{d}n$

# %% [markdown]
# <h3 style="display:inline">(7)</h3> $\displaystyle\prod_{k=1}^{n}c^k$

# %% [markdown]
# <h3 style="display:inline">(8)</h3> $\displaystyle\sum_{k=n/2}^{n}k^4$

# %% [markdown]
# <h3 style="display:inline">(9)</h3> give asymptotically tight bounds for $\displaystyle\sum_{k=1}^{n}k^r$

# %% [markdown]
# <h3 style="display:inline">(10)</h3> give asymptotically tight bounds for $\displaystyle\sum_{k=1}^{n}lg^kk$
