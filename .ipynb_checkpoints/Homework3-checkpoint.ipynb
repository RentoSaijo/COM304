# %% [markdown]
# # Homework 3

# %% [markdown]
# Note: Our group (Kymmani and I) spent 4 hours working together on February 23rd at 5:30 PM. I'm not exactly sure what's going on with our other groupmate, Jaiden. We haven't been able to contact her.

# %% [markdown]
# 1.
